# %%
import pickle

with open("vocabulary_radius0_structural_guacamol_v1.pkl", "rb") as file:
    data = pickle.load(file)

# %%
data
# Out:
# {3218693969: 1,
#  2968968094: 2,
#  3217380708: 3,
#  2246728737: 4,
#  2245384272: 5,
#  864942730: 6,
#  2246699815: 7,
#  2976033787: 8,
#  2041434490: 9,
#  2092489639: 10,
#  847961216: 11,
#  864674487: 12,
#  2245273601: 13,
#  882399112: 14,
#  3189457552: 15,
#  2976816164: 16,
#  2245277810: 17,
#  2143075994: 18,
#  848128881: 19,
#  2132511834: 20,
#  3351556771: 21,
#  864662311: 22,
#  1016841875: 23,
#  999334238: 24,
#  847690172: 25,
#  2245900962: 26,
#  2246703798: 27,
#  864942795: 28,
#  3612926680: 29,
#  847433064: 30,
#  847957139: 31,
#  847867887: 32,
#  1026928756: 33,
#  2246997334: 34,
#  848127915: 35,
#  2130998634: 36,
#  2114006677: 37,
#  847694221: 38,
#  2041738475: 39,
#  2865977551: 40,
#  847336149: 41,
#  2245897107: 42,
#  1026654305: 43,
#  999602603: 44,
#  319552149: 45,
#  847958490: 46,
#  2850007887: 47,
#  847954377: 48,
#  2092554703: 49,
#  847342868: 50,
#  1026924773: 51,
#  849275503: 52,
#  4277593716: 53,
#  3388977530: 54,
# ...
