# %%
import pickle

with open("vocabulary_radius0_structural_guacamol_v1.pkl", "rb") as file:
    data = pickle.load(file)

# %%
import pickle

with open(
    "../mole/data/vocabularies/vocabulary_207atomenvs_radius0_ZINC_guacamole.pkl", "rb"
) as file:
    data_paper = pickle.load(file)

# %%
import pickle

with open(
    "../mole/data/vocabularies/vocabulary_radius0_structural_guacamol_v1.pkl", "rb"
) as file:
    data_gc = pickle.load(file)

data_gc
# Out:
# {3218693969: 1,
#  3217380708: 2,
#  2968968094: 3,
#  2245384272: 4,
#  2246728737: 5,
#  864942730: 6,
#  2246699815: 7,
#  2041434490: 8,
#  2092489639: 9,
#  2976033787: 10,
#  847961216: 11,
#  864674487: 12,
#  864662311: 13,
#  882399112: 14,
#  3189457552: 15,
#  2245273601: 16,
#  1016841875: 17,
#  2132511834: 18,
#  2976816164: 19,
#  2246703798: 20,
#  847957139: 21,
#  3351556771: 22,
#  2245277810: 23,
#  999334238: 24,
#  848128881: 25,
#  847336149: 26,
#  2245900962: 27,
#  1026928756: 28,
#  847433064: 29,
#  864942795: 30,
#  3612926680: 31,
#  848127915: 32,
#  2246997334: 33,
#  1026654305: 34,
#  849275503: 35,
#  984189120: 36,
#  2092554703: 37,
#  2865977551: 38,
#  1026924773: 39,
#  319552149: 40,
#  2245897107: 41,
#  999602538: 42,
#  847698334: 43,
#  849271271: 44,
#  2114539071: 45,
#  847433129: 46,
#  3388977530: 47,
#  1844282154: 48,
#  2197104911: 49,
#  2850012158: 50,
#  4274663090: 51,
#  3595956281: 52,
#  3206345777: 53,
#  2245108812: 54,
# ...

# %%
import pickle

with open(
    "../mole/data/vocabularies/vocabulary_radius1_functional_guacamol_v1_count.pkl", "rb"
) as file:
    data_count = pickle.load(file)

len(data_count)
# Out:
# 1468

# %%
len([(x,y) for x,y in data_count if y >100])
# Out:
# 603

# %%
len({x:y  for x,y in data.items() if x not in data_gc.keys()})
# Out:
# 45

# %%
len({x: y for x, y in data_gc.items() if x not in data.keys()})
# Out:
# 56

# %%
{x: y for x, y in data_count if x not in data_paper.keys()}
# Out:
# {4274674979: 4, 3215713989: 1, 999598587: 1, 319173395: 1, 999598457: 1}

# %%
{x: y for x, y in data.items() if x not in data_paper.keys()}
# Out:
# {4277593716: 53,
#  11598140: 122,
#  996772513: 128,
#  1026928951: 131,
#  3156020739: 136,
#  849275566: 143,
#  999602408: 148,
#  2849921308: 154,
#  'PAD': 0,
#  'MASK': 159,
#  'UNK': 160,
#  'CLS': 161}

# %%
{x: y for x, y in data_paper.items() if x not in data.keys()}
# Out:
# {2866325538: 14,
#  2246997269: 112,
#  3912561944: 116,
#  11594061: 141,
#  321854373: 178,
#  2197215675: 188}

# %%
data.update(data_gc)
